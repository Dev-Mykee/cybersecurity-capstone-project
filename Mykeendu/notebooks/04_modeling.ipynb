# %% [markdown]
# # 04 - Modeling (Optional)
#
# - Model training
# - Evaluation metrics
# - Interpretation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
