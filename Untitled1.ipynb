# %%
print("Hello, Python")
# Out:
# Hello, Python

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn 
import tensorflow as tf 
import flask

# %%
import pandas as pd # Load from CSV 
df = pd.read_csv(r"C:\Users\ofoeg\myproject\Attack_Dataset.csv") 
# Load from JSON 
#df_json = pd.read_json("sample_data.json") 
# Preview the data 
df.head()
df.describe()
# Out:
#                  ID
# count  14133.000000
# mean    7067.000000
# std     4079.990012
# min        1.000000
# 25%     3534.000000
# 50%     7067.000000
# 75%    10600.000000
# max    14133.000000
